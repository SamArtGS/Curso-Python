# %%
#Problema 16 de https://projecteuler.net/problem=16

#215 = 32768 and the sum of its digits is 3 + 2 + 7 + 6 + 8 = 26.
#What is the sum of the digits of the number 2^1000?

valor=2**1000 #variable con exponente
valor=str(valor)
print('El valor de 2^1000= ')
print(value) #Imprimir valor

lista=[]
for x in valor:
	lista.append(int(x)) #se transforma en entero
print("")
print('****RESULTADO*****')
print(sum(lista)) #suma de elementos
# Out:
# El valor de 2^1000=
# ...
#
# ****RESULTADO*****
# 1366
